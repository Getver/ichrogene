# %% [markdown]
# <a href="https://colab.research.google.com/github/Getver/ichrogene/blob/main/histogram/PRS_histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# test1 neuropathy

setwd('/content')
data <- read.csv('neuropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 20.8397  Control
# 2 1547110_1547110 1547110_1547110 22.2203  Control
# 3 1417055_1417055 1417055_1417055 20.1940  Control
# 4 5301177_5301177 5301177_5301177 23.4472  Control
# 5 2671862_2671862 2671862_2671862 17.7674  Control
# 6 4535478_4535478 4535478_4535478 22.9387  Control
# plot without title

# %%
# test2 neuropathy

setwd('/content')
data <- read.csv('neuropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 22.3140  Control
# 2 1547110_1547110 1547110_1547110 24.1508  Control
# 3 1417055_1417055 1417055_1417055 21.6683  Control
# 4 5301177_5301177 5301177_5301177 24.9215  Control
# 5 2671862_2671862 2671862_2671862 19.2417  Control
# 6 4535478_4535478 4535478_4535478 24.8692  Control
# plot without title

# %%
# test3 neuropathy

setwd('/content')
data <- read.csv('neuropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 42.1311  Control
# 2 1547110_1547110 1547110_1547110 44.5631  Control
# 3 1417055_1417055 1417055_1417055 37.4739  Control
# 4 5301177_5301177 5301177_5301177 43.2734  Control
# 5 2671862_2671862 2671862_2671862 32.4368  Control
# 6 4535478_4535478 4535478_4535478 38.4266  Control
# plot without title

# %%
# test4 neuropathy

setwd('/content')
data <- read.csv('neuropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 71.1436  Control
# 2 1547110_1547110 1547110_1547110 75.3297  Control
# 3 1417055_1417055 1417055_1417055 67.9220  Control
# 4 5301177_5301177 5301177_5301177 76.7473  Control
# 5 2671862_2671862 2671862_2671862 65.8548  Control
# 6 4535478_4535478 4535478_4535478 70.2308  Control
# plot without title

# %%
# test1 nephropathy

setwd('/content')
data <- read.csv('nephropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 25.1582  Control
# 2 1547110_1547110 1547110_1547110 22.9505  Control
# 3 1417055_1417055 1417055_1417055 22.6423  Control
# 4 5301177_5301177 5301177_5301177 20.3413  Control
# 5 2671862_2671862 2671862_2671862 31.2633  Control
# 6 4535478_4535478 4535478_4535478 22.0885  Control
# plot without title

# %%
# test2 nephropathy

setwd('/content')
data <- read.csv('nephropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 10.55940 Control
# 2 1547110_1547110 1547110_1547110 12.33480 Control
# 3 1417055_1417055 1417055_1417055 10.18550 Control
# 4 5301177_5301177 5301177_5301177  9.51354 Control
# 5 2671862_2671862 2671862_2671862 13.14240 Control
# 6 4535478_4535478 4535478_4535478  8.98108 Control
# plot without title

# %%
# test3 nephropathy

setwd('/content')
data <- read.csv('nephropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544  95.7508 Control
# 2 1547110_1547110 1547110_1547110 109.1920 Control
# 3 1417055_1417055 1417055_1417055 111.4170 Control
# 4 5301177_5301177 5301177_5301177 114.0150 Control
# 5 2671862_2671862 2671862_2671862 118.0130 Control
# 6 4535478_4535478 4535478_4535478 118.7100 Control
# plot without title

# %%
# test1 retinopathy

setwd('/content')
data <- read.csv('retinopathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 0.211455 Control
# 2 1547110_1547110 1547110_1547110 0.895360 Control
# 3 1417055_1417055 1417055_1417055 1.297280 Control
# 4 5301177_5301177 5301177_5301177 0.400932 Control
# 5 2671862_2671862 2671862_2671862 0.871523 Control
# 6 4535478_4535478 4535478_4535478 0.401103 Control
# plot without title

# %%
# test2 retinopathy

setwd('/content')
data <- read.csv('retinopathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 7.91457  Control
# 2 1547110_1547110 1547110_1547110 8.67253  Control
# 3 1417055_1417055 1417055_1417055 9.88338  Control
# 4 5301177_5301177 5301177_5301177 9.33016  Control
# 5 2671862_2671862 2671862_2671862 8.59471  Control
# 6 4535478_4535478 4535478_4535478 8.59991  Control
# plot without title

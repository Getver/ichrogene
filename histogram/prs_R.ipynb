# %% [markdown]
# <a href="https://colab.research.google.com/github/Getver/ichrogene/blob/main/histogram/prs_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
library(dplyr)

# %%
setwd('/content')
data <- read.csv('nephropathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 0.00000  Control
# 2 1547110_1547110 1547110_1547110 0.00000  Control
# 3 1417055_1417055 1417055_1417055 0.00000  Control
# 4 5301177_5301177 5301177_5301177 0.00000  Control
# 5 2671862_2671862 2671862_2671862 2.24177  Control
# 6 4535478_4535478 4535478_4535478 0.45770  Control
# plot without title

# %%
setwd('/content')
data <- read.csv('retinopathy_addPheno.csv', header = T)
head(data)


ggplot(data, aes(x=SCORESUM, fill=PHENO)) +
  geom_density(position='identity', alpha=0.4) +
  scale_color_manual(values = c("#DB4035", "#4073FF")) +
  theme_light()
# Out:
#   FID             IID             SCORESUM PHENO
# 1 3997544_3997544 3997544_3997544 0.211455 Control
# 2 1547110_1547110 1547110_1547110 0.895360 Control
# 3 1417055_1417055 1417055_1417055 1.297280 Control
# 4 5301177_5301177 5301177_5301177 0.400932 Control
# 5 2671862_2671862 2671862_2671862 0.871523 Control
# 6 4535478_4535478 4535478_4535478 0.401103 Control
# plot without title
